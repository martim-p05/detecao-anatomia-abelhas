# %% [markdown]
# <a href="https://colab.research.google.com/github/martim-p05/detecao-anatomia-abelhas/blob/main/abelhas_detecao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ATENÇÃO: Altere os caminhos abaixo para corresponderem às pastas da Drive

caminho_modelo = '/content/drive/MyDrive/abelhas/best.pt'
pasta_origem_fotos = '/content/drive/MyDrive/abelhas/museu_teste_codigo'
pasta_final = '/content/drive/MyDrive/abelhas/museu_fotos_alt'

# %%
from ultralytics import YOLO
modelo=YOLO(caminho_modelo)
modelo.predict(source=pasta_origem_fotos, save=True, save_txt=True,
               project=pasta_final, name='teste_5_fotos')
# Out:
# image 1/5 /content/drive/MyDrive/abelhas/museu_teste_codigo/Apis_mellifera_MNHNCENT0046577_13.tif: 608x800 2 abdomens, 2 asass, 1 cabeca, 649.3ms
# image 2/5 /content/drive/MyDrive/abelhas/museu_teste_codigo/Apis_mellifera_MNHNCENT0046577_14.tif: 608x800 1 abdomen, 2 asass, 1 cabeca, 651.1ms
# image 3/5 /content/drive/MyDrive/abelhas/museu_teste_codigo/Apis_mellifera_MNHNCENT0046577_15.tif: 608x800 1 abdomen, 3 asass, 1 cabeca, 666.3ms
# image 4/5 /content/drive/MyDrive/abelhas/museu_teste_codigo/Apis_mellifera_MNHNCENT0046577_16.tif: 608x800 1 abdomen, 1 asas, 1 cabeca, 693.4ms
# image 5/5 /content/drive/MyDrive/abelhas/museu_teste_codigo/Apis_mellifera_MNHNCENT0046577_17.tif: 608x800 2 abdomens, 2 asass, 1 cabeca, 685.3ms
# Speed: 6.6ms preprocess, 669.1ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 800)
# Results saved to /content/drive/MyDrive/abelhas/museu_fotos_alt/teste_5_fotos
# 5 labels saved to /content/drive/MyDrive/abelhas/museu_fotos_alt/teste_5_fotos/labels
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'abdomen', 1: 'asas', 2: 'cabeca'}
#  obb: None
#  orig_img: array([[[164, 152, 154],
#          [164, 157, 157],
#          [161, 156, 157],
#          ...,
#          [133, 134, 130],
#          [133, 134, 133],
#          [133, 133, 134]],
#
#         [[162, 152, 154],
#          [162, 154, 155],
#          [156, 151, 154],
#          ...,
#          [136, 134, 133],
#          [134, 133, 131],
#          [132, 131, 131]],
#
#         [[161, 154, 157],
#          [157, 152, 157],
#          [154, 152, 159],
#          ...,
#          [137, 134, 134],
#          [134, 132, 133],
#          [133, 131, 131]],
#
#         ...,
#
#         [[149, 145, 148],
#          [149, 143, 148],
#          [149, 145, 150],
#          ...,
#          [138, 141, 138],
#          [137, 143, 141],
#          [136, 143, 139]],
#
#         [[151, 145, 146],
#          [151, 145, 150],
#          [153, 146, 150],
#          ...,
#          [140, 141, 138],
#          [140, 143, 140],
#          [139, 143, 139]],
#
#         [[151, 145, 145],
#          [154, 147, 146],
#          [153, 146, 146],
#          ...,
#          [141, 143, 140],
#          [144, 143, 140],
#          [142, 143, 140]]], dtype=uint8)
#  orig_shape: (1886, 2511)
#  path: '/content/drive/MyDrive/abelhas/museu_teste_codigo/Apis_mellifera_MNHNCENT0046577_13.tif'
#  probs: None
#  save_dir: '/content/drive/MyDrive/abelhas/museu_fotos_alt/teste_5_fotos'
#  speed: {'preprocess': 6.646304999776476, 'inference': 649.3275369998628, 'postprocess': 1.4966779999667779},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'abdomen', 1: 'asas', 2: 'cabeca'}
#  obb: None
#  orig_img: array([[[154, 153, 153],
#          [154, 153, 156],
#          [156, 154, 159],
#          ...,
#          [145, 143, 147],
#          [141, 142, 147],
#          [141, 145, 147]],
#
#         [[154, 151, 151],
#          [154, 149, 151],
#          [154, 151, 153],
#          ...,
#          [149, 143, 147],
#          [145, 143, 145],
#          [145, 147, 147]],
#
#         [[154, 149, 151],
#          [156, 149, 151],
#          [156, 149, 150],
#          ...,
#          [148, 145, 148],
#          [145, 145, 145],
#          [147, 147, 147]],
#
#         ...,
#
#         [[149, 145, 146],
#          [150, 145, 146],
#          [152, 145, 144],
#          ...,
#          [157, 156, 155],
#          [157, 156, 157],
#          [155, 153, 155]],
#
#         [[154, 149, 148],
#          [154, 147, 146],
#          [150, 145, 143],
#          ...,
#          [155, 155, 154],
#          [152, 150, 149],
#          [155, 153, 152]],
#
#         [[155, 149, 148],
#          [154, 147, 146],
#          [152, 147, 144],
#          ...,
#          [152, 150, 149],
#          [149, 148, 146],
#          [155, 153, 150]]], dtype=uint8)
#  orig_shape: (1892, 2524)
#  path: '/content/drive/MyDrive/abelhas/museu_teste_codigo/Apis_mellifera_MNHNCENT0046577_14.tif'
#  probs: None
#  save_dir: '/content/drive/MyDrive/abelhas/museu_fotos_alt/teste_5_fotos'
#  speed: {'preprocess': 10.357947000102286, 'inference': 651.1151740000969, 'postprocess': 0.9963210000023537},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'abdomen', 1: 'asas', 2: 'cabeca'}
#  obb: None
#  orig_img: array([[[164, 157, 156],
#          [168, 157, 156],
#          [168, 154, 159],
#          ...,
#          [153, 148, 151],
#          [153, 150, 149],
#          [153, 152, 151]],
#
#         [[161, 157, 155],
#          [164, 157, 156],
#          [168, 154, 157],
#          ...,
#          [158, 152, 153],
#          [154, 148, 151],
#          [153, 152, 151]],
#
#         [[160, 156, 154],
#          [161, 156, 154],
#          [164, 156, 157],
#          ...,
#          [158, 152, 151],
#          [156, 150, 149],
#          [154, 148, 151]],
#
#         ...,
#
#         [[158, 148, 151],
#          [158, 144, 149],
#          [154, 147, 148],
#          ...,
#          [139, 138, 140],
#          [140, 138, 140],
#          [144, 140, 140]],
#
#         [[156, 144, 146],
#          [156, 147, 146],
#          [154, 150, 146],
#          ...,
#          [142, 140, 140],
#          [144, 140, 142],
#          [145, 143, 145]],
#
#         [[158, 144, 145],
#          [158, 147, 146],
#          [156, 150, 146],
#          ...,
#          [144, 140, 137],
#          [144, 140, 138],
#          [145, 140, 140]]], dtype=uint8)
#  orig_shape: (1893, 2527)
#  path: '/content/drive/MyDrive/abelhas/museu_teste_codigo/Apis_mellifera_MNHNCENT0046577_15.tif'
#  probs: None
#  save_dir: '/content/drive/MyDrive/abelhas/museu_fotos_alt/teste_5_fotos'
#  speed: {'preprocess': 5.059485999936442, 'inference': 666.2646370000402, 'postprocess': 0.8838139997351391},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'abdomen', 1: 'asas', 2: 'cabeca'}
#  obb: None
#  orig_img: array([[[169, 145, 150],
#          [167, 145, 150],
#          [166, 145, 150],
#          ...,
#          [150, 151, 153],
#          [153, 154, 160],
#          [153, 154, 163]],
#
#         [[166, 148, 151],
#          [168, 150, 154],
#          [168, 150, 154],
#          ...,
#          [148, 151, 149],
#          [150, 151, 155],
#          [148, 149, 155]],
#
#         [[161, 153, 154],
#          [162, 153, 154],
#          [170, 156, 159],
#          ...,
#          [147, 151, 146],
#          [147, 148, 147],
#          [142, 144, 146]],
#
#         ...,
#
#         [[152, 141, 142],
#          [152, 141, 142],
#          [154, 144, 145],
#          ...,
#          [145, 147, 142],
#          [140, 146, 139],
#          [138, 144, 138]],
#
#         [[156, 144, 143],
#          [156, 144, 143],
#          [155, 144, 142],
#          ...,
#          [143, 143, 137],
#          [140, 145, 137],
#          [141, 147, 138]],
#
#         [[156, 144, 140],
#          [158, 144, 140],
#          [155, 141, 137],
#          ...,
#          [141, 142, 135],
#          [143, 148, 137],
#          [143, 150, 138]]], dtype=uint8)
#  orig_shape: (1920, 2560)
#  path: '/content/drive/MyDrive/abelhas/museu_teste_codigo/Apis_mellifera_MNHNCENT0046577_16.tif'
#  probs: None
#  save_dir: '/content/drive/MyDrive/abelhas/museu_fotos_alt/teste_5_fotos'
#  speed: {'preprocess': 4.715863999990688, 'inference': 693.3893609998449, 'postprocess': 1.0322729999643343},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'abdomen', 1: 'asas', 2: 'cabeca'}
#  obb: None
#  orig_img: array([[[146, 139, 141],
#          [147, 145, 145],
#          [146, 145, 147],
#          ...,
#          [132, 135, 132],
#          [132, 134, 132],
#          [132, 131, 129]],
#
#         [[146, 140, 142],
#          [149, 145, 147],
#          [149, 145, 149],
#          ...,
#          [137, 140, 135],
#          [137, 140, 137],
#          [137, 135, 132]],
#
#         [[146, 142, 145],
#          [147, 147, 147],
#          [152, 147, 150],
#          ...,
#          [139, 140, 135],
#          [139, 140, 135],
#          [139, 139, 133]],
#
#         ...,
#
#         [[161, 159, 159],
#          [163, 161, 159],
#          [166, 163, 157],
#          ...,
#          [154, 148, 147],
#          [154, 151, 151],
#          [154, 153, 151]],
#
#         [[161, 158, 156],
#          [164, 159, 157],
#          [166, 163, 157],
#          ...,
#          [154, 151, 147],
#          [154, 153, 151],
#          [154, 155, 153]],
#
#         [[163, 158, 156],
#          [164, 159, 156],
#          [166, 163, 157],
#          ...,
#          [156, 155, 149],
#          [154, 153, 151],
#          [153, 151, 151]]], dtype=uint8)
#  orig_shape: (1887, 2520)
#  path: '/content/drive/MyDrive/abelhas/museu_teste_codigo/Apis_mellifera_MNHNCENT0046577_17.tif'
#  probs: None
#  save_dir: '/content/drive/MyDrive/abelhas/museu_fotos_alt/teste_5_fotos'
#  speed: {'preprocess': 6.3602950003769365, 'inference': 685.2808140001798, 'postprocess': 1.1246499998378567}]
