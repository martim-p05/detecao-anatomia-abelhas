# %% [markdown]
# <a href="https://colab.research.google.com/github/martim-p05/detecao-anatomia-abelhas/blob/main/script_treino_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Treino do modelo YOLOv8

# %% [markdown]
# Treino 75 épocas de 425 fotos, exportadas a partir do Roboflow

# %%
# !nvidia-smi
# !pip install ultralytics -q

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Crlfcj2fjisAK5FAYhtT")
project = rf.workspace("object-detection-2ytnp").project("segmentacao_abelhas")
version = project.version(3)
dataset = version.download("yolov8")

# %%
# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=75 imgsz=800 plots=True

# %%
from google.colab import drive
drive.mount('/content/drive')

# !cp /content/runs/detect/train/weights/best.pt /content/drive/MyDrive/abelhas/best.pt
